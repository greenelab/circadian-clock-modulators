# %% [markdown]
# ## Read FDA compounds
#
# https://github.com/greenelab/circadian-clock-modulators/issues/1
#
# > The SCREENWELL FDA-approved drug library V2 containing 741 compounds was purchased from Enzo Life Sciences (Hayashi Kasei Co., Ltd.), and the International Drug Collection (IDC) containing 311 compounds was purchased from MicroSource Discovery Systems, Inc. (Namiki Shoji Co., Ltd.).

# %%
import logging

import pandas
import requests_cache

from utils.pubchem import query_pubchem_for_drugbank

# %%
requests_cache.install_cache(cache_name="requests-cache", allowable_codes=[200, 404])

# %% [markdown]
# ### Read tamai screen results

# %%
screen_df = pandas.read_table("data/tamai-screen/combined-results.tsv")
screen_df.head(2)
# Out:
#      compound_name compound_set concentration  period_before  period_change  \
# 0  Clindamycin·HCl          fda          1 uM           21.5        0.02917
# 1        Felbamate          fda          1 uM           21.7        0.06250
#
#    plate notes
# 0      1   NaN
# 1      1   NaN

# %% [markdown]
# ### Read Screen-Well compounds
#
# The spreadsheet contains chemical structures in `mrv` format (ChemAxon MRV format, [Marvin Document](https://docs.chemaxon.com/display/docs/Marvin_Documents_-_MRV.html)). This format appears to be propreitary / not well supported, so map via other fields instead.

# %%
# mrv (ChemAxon MRV format)
xlsx_path = "data/compounds/BML-2843_v. 1.4_Rev. 18Dec19_StructureFile.xlsx"
structure_df = pandas.read_excel(xlsx_path, sheet_name=0)
structure_df.head(2)
# Out:
#                                Hash  StructureStringLength  \
# 0  50A647B589F94DEB7D0CBA1EAE819980                      1
# 1  C725614FF6722BF574DB2EE705636395                      1
#
#   StructureStringFormat                                    StructureString
# 0                   mrv  JChemExcelFgsAAB+LCAAAAAAABADtvQdgHEmWJSYvbcp7...
# 1                   mrv  JChemExcelogYAAB+LCAAAAAAABADtvQdgHEmWJSYvbcp7...

# %%
screenwell_df = pandas.read_excel(xlsx_path, sheet_name=1).add_prefix("screenwell_").convert_dtypes()
# fix messy column names
screenwell_df.columns = screenwell_df.columns.str.strip().str.lower().str.replace(" ", "_")
# remove blank rows
screenwell_df = screenwell_df.query("screenwell_name != 'Blank'")
screenwell_df.head(2)
# Out:
#    screenwell_structure                                  screenwell_smiles  \
# 0                  <NA>  CCC[C@@H]1CC(N(C1)C)C(=O)N[C@@H](C2[C@@H]([C@H...
# 1                  <NA>                   C1=CC=C(C=C1)C(COC(=O)N)COC(=O)N
#
#                                     screenwell_iupac  \
# 0  (4R)-N-[(1S,2S)-2-chloro-1-[(3R,4R,6R)-3,4,5-t...
# 1          (3-carbamoyloxy-2-phenylpropyl) carbamate
#
#   screenwell_plate_location screenwell_catalog_number    screenwell_name  \
# 0                     1-A02                      A190  Clindamycin · HCl
# 1                     1-A03                     DL567          Felbamate
#
#   screenwell_cas screenwell_mw screenwell_concentration screenwell_solvent  \
# 0     21462-39-5         461.4                    10 mM               DMSO
# 1     25451-15-4         238.2                    10 mM               DMSO
#
#    screenwell_plate_number screenwell_plate_description  \
# 0                        1               FDA Library II
# 1                        1               FDA Library II
#
#   screenwell_approval_year screenwell_indication  \
# 0                     1970            Antibiotic
# 1                     1993        Anticonvulsant
#
#                       screenwell_mechanism_of_action  \
# 0  Systemic/vaginal clindamycin inhibits protein ...
# 1  Precise mechanism unknown; It has an effect on...
#
#                            screenwell_notes/toxicity  \
# 0  Side effects include: diarrhea, pseudomembrano...
# 1  Adverse reactions include decreased appetite, ...
#
#    screenwell_plate_part_number
# 0                          2843
# 1                          2843

# %%
# Number of compound names in the screen where exact text match fails
screen_names = sorted(screen_df.query("compound_set == 'fda'").compound_name.unique())
len(set(screen_names) - set(screenwell_df.screenwell_name))
# Out:
# 152

# %%
# %%time
rows = []
for screenwell in screenwell_df.itertuples():
    for by, compound_name in [
            ("name", screenwell.screenwell_iupac),
            ("smiles", screenwell.screenwell_smiles),
            ("name", screenwell.screenwell_name),
        ]:
        row = query_pubchem_for_drugbank(compound_name, by=by)
        if row:
            break
    else:
        logging.warning(f"IUPAC lookup failed for {screenwell.screenwell_name}")
        continue
    row["screenwell_name"] = screenwell.screenwell_name
    rows.append(row)
len(rows)
# Out:
# WARNING:root:IUPAC lookup failed for Ranitidine·HCl
# WARNING:root:IUPAC lookup failed for Cefepime·2HCl Hydrate
# WARNING:root:IUPAC lookup failed for Terazosin·HCl
# WARNING:root:IUPAC lookup failed for Ceftizoxim·Na
# WARNING:root:IUPAC lookup failed for Ceftriaxone·Na
# WARNING:root:IUPAC lookup failed for Cefuroxime·Na
# WARNING:root:IUPAC lookup failed for Dantrolene . sodium
# WARNING:root:IUPAC lookup failed for Demeclocycline·HCl
# CPU times: user 4.27 s, sys: 292 ms, total: 4.56 s
# Wall time: 37.5 s
# 764

# %%
screenwell_map_df = (
    screenwell_df
    [["screenwell_name", "screenwell_catalog_number", "screenwell_plate_location", "screenwell_smiles", "screenwell_iupac"]]
    .merge(pandas.DataFrame(rows), how="left")
    .convert_dtypes()
)
screenwell_map_df.head(5)
# Out:
#               screenwell_name screenwell_catalog_number  \
# 0           Clindamycin · HCl                      A190
# 1                   Felbamate                     DL567
# 2               Cyclosporin A                      A195
# 3               Donepezil·HCl                     DL568
# 4  Lincomycin·HCl monohydrate                      A240
#
#   screenwell_plate_location  \
# 0                     1-A02
# 1                     1-A03
# 2                     1-A04
# 3                     1-A05
# 4                     1-A06
#
#                                    screenwell_smiles  \
# 0  CCC[C@@H]1CC(N(C1)C)C(=O)N[C@@H](C2[C@@H]([C@H...
# 1                   C1=CC=C(C=C1)C(COC(=O)N)COC(=O)N
# 2  CC[C@H]1C(=O)N(CC(=O)N([C@H](C(=O)N[C@H](C(=O)...
# 3  COC1=C(C=C2C(=C1)CC(C2=O)CC3CCN(CC3)CC4=CC=CC=...
# 4  CCCC1CC(N(C1)C)C(=O)NC(C2C(C(C(C(O2)SC)O)O)O)C...
#
#                                     screenwell_iupac  \
# 0  (4R)-N-[(1S,2S)-2-chloro-1-[(3R,4R,6R)-3,4,5-t...
# 1          (3-carbamoyloxy-2-phenylpropyl) carbamate
# 2  (3S,6S,9S,12R,15S,18S,21S,24S,30S,33S)-30-ethy...
# 3  2-[(1-benzylpiperidin-4-yl)methyl]-5,6-dimetho...
# 4  (2S,4R)-N-[(1R,2R)-2-hydroxy-1-[(2R,3R,4S,5R,6...
#
#                                       query_compound  pubchem_cid drugbank_id
# 0  CCC[C@@H]1CC(N(C1)C)C(=O)N[C@@H](C2[C@@H]([C@H...     53384906        <NA>
# 1          (3-carbamoyloxy-2-phenylpropyl) carbamate         3331     DB00949
# 2                                      Cyclosporin A      5284373     DB00091
# 3  2-[(1-benzylpiperidin-4-yl)methyl]-5,6-dimetho...         5741        <NA>
# 4  (2S,4R)-N-[(1R,2R)-2-hydroxy-1-[(2R,3R,4S,5R,6...      3000540     DB01627

# %%
print(f"""
{(screenwell_map_df.query_compound == screenwell_map_df.screenwell_iupac).sum():,} compounds mapped to pubchem via screenwell_iupac
{(screenwell_map_df.query_compound == screenwell_map_df.screenwell_smiles).sum():,} compounds mapped to pubchem via screenwell_smiles
{(screenwell_map_df.query_compound == screenwell_map_df.screenwell_name).sum():,} compounds mapped to pubchem via screenwell_name
{sum(screenwell_map_df.pubchem_cid.isna()):,} compounds failed to map to pubchem

{sum(screenwell_map_df.drugbank_id.notna()):,} compounds mapped to DrugBank
""".strip())
# Out:
# 557 compounds mapped to pubchem via screenwell_iupac
# 191 compounds mapped to pubchem via screenwell_smiles
# 33 compounds mapped to pubchem via screenwell_name
# 8 compounds failed to map to pubchem
#
# 406 compounds mapped to DrugBank

# %%
# Screen-Well compounds not mapped to PubChem
screenwell_map_df[screenwell_map_df.pubchem_cid.isna()]
# Out:
#            screenwell_name screenwell_catalog_number  \
# 61          Ranitidine·HCl                     AC766
# 88   Cefepime·2HCl Hydrate                     DL191
# 342          Terazosin·HCl                     DL513
# 449          Ceftizoxim·Na                    AC3053
# 450         Ceftriaxone·Na                    AC3054
# 452          Cefuroxime·Na                    AC3056
# 483    Dantrolene . sodium                    550072
# 492     Demeclocycline·HCl                    AC3083
#
#     screenwell_plate_location  \
# 61                      1-G03
# 88                      2-A10
# 342                     5-C05
# 449                     6-H03
# 450                     6-H04
# 452                     6-H06
# 483                     7-C10
# 492                     7-D09
#
#                                      screenwell_smiles  \
# 61     CN/C(=C/[N+](=O)[O-])/NCCSCC1=CC=C(O1)CN(C)C.Cl
# 88   [H+].C[N+]1(CCCC1)CC2=C(N3C(C(C3=O)NC(=O)/C(=N...
# 342  COC1=C(C=C2C(=C1)C(=NC(=N2)N3CCN(CC3)C(=O)C4CC...
# 449  CO/N=C(\C1=CSC(=N1)N)/C(=O)N[C@H]2[C@@H]3N(C2=...
# 450  CN1C(=NC(=O)C(=O)N1)SCC2=C(N3[C@@H]([C@@H](C3=...
# 452  CO/N=C(\C1=CC=CO1)/C(=O)N[C@H]2[C@@H]3N(C2=O)C...
# 483  C1C(=O)N=C(N1/N=C/C2=CC=C(O2)C3=CC=C(C=C3)[N+]...
# 492  CN(C)[C@H]1[C@@H]2C[C@@H]3[C@@H](C4=C(C=CC(=C4...
#
#                                       screenwell_iupac query_compound  \
# 61   (Z)-1-N'-[2-[[5-[(dimethylamino)methyl]furan-2...           <NA>
# 88   7-[[(2Z)-2-(2-amino-1,3-thiazol-4-yl)-2-methox...           <NA>
# 342  [4-(4-amino-6,7-dimethoxyquinazolin-2-yl)piper...           <NA>
# 449  sodium;(6R,7R)-7-[[(2E)-2-(2-amino-1,3-thiazol...           <NA>
# 450  sodium;7-[[(2Z)-2-(2-amino-1,3-thiazol-4-yl)-2...           <NA>
# 452  sodium;(6R,7R)-3-(carbamoyloxymethyl)-7-[[(2E)...           <NA>
# 483  sodium;3-[(E)-[5-(4-nitrophenyl)furan-2-yl]met...           <NA>
# 492  (4S,4aS,5aS,6S,12aR)-7-chloro-4-(dimethylamino...           <NA>
#
#      pubchem_cid drugbank_id
# 61          <NA>        <NA>
# 88          <NA>        <NA>
# 342         <NA>        <NA>
# 449         <NA>        <NA>
# 450         <NA>        <NA>
# 452         <NA>        <NA>
# 483         <NA>        <NA>
# 492         <NA>        <NA>

# %%
screenwell_map_df.to_csv("data/compounds/screenwell-to-pubchem.tsv", sep="\t", index=False)
