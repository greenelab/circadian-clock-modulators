# %% [markdown]
# ## Read FDA compounds
#
# https://github.com/greenelab/circadian-clock-modulators/issues/1
#
# > The SCREENWELL FDA-approved drug library V2 containing 741 compounds was purchased from Enzo Life Sciences (Hayashi Kasei Co., Ltd.), and the International Drug Collection (IDC) containing 311 compounds was purchased from MicroSource Discovery Systems, Inc. (Namiki Shoji Co., Ltd.).

# %%
import pandas

# %%
screen_df = pandas.read_table("data/tamai-screen/combined-results.tsv")
screen_df.head(2)
# Out:
#      compound_name compound_set concentration  period_before  period_change  \
# 0  Clindamycin·HCl          fda          1 uM           21.5        0.02917
# 1        Felbamate          fda          1 uM           21.7        0.06250
#
#    plate
# 0      1
# 1      1

# %%
sorted(screen_df.query("compound_set == 'fda'").compound_name.unique())
# Out:
# ['(S)-Timolol Maleate',
#  '(±) Isoproterenol·HCl ',
#  '(±)-Atenolol',
#  '4-Aminosalicylic Acid',
#  'Abacavir Sulfate',
#  'Acamprosate ',
#  'Acarbose',
#  'Acebutolol·HCl',
#  'Acetaminophen',
#  'Acetazolamide',
#  'Acetohexamide',
#  'Acetohydroxamic Acid',
#  'Acetylcholine Chloride',
#  'Acetylcysteine',
#  'Acitretin',
#  'Acrivastine',
#  'Acyclovir (Acycloguanosine) Zovirax',
#  'Adapalene',
#  'Adefovir Dipivoxil',
#  'Adenosine',
#  'Albendazole',
#  'Alendronate·Na Trihydrate',
#  'Alfuzosin',
#  'Alitretinoin',
#  'Allopurinol',
#  'Almotriptan',
#  'Alosetron·HCl',
#  'Alprostadil',
#  'Altretamine',
#  'Amantadine·HCl',
#  'Ambrisentan',
#  'Amcinonide',
#  'Amifostine',
#  'Amikacin Disulfate',
#  'Amiloride·HCl·2H2O',
#  'Aminocaproic Acid',
#  'Aminohippurate·Na',
#  'Aminolevulinic Acid·HCl',
#  'Aminophylline ',
#  'Amiodarone·HCl',
#  'Amitriptyline·HCl',
#  'Amlexanox',
#  'Amlodipine',
#  'Amoxapine',
#  'Amoxicillin',
#  'Amphotericin B',
#  'Ampicillin Trihydrate',
#  'Amrinone',
#  'Anagrelide',
#  'Anastrozole',
#  'Apomorphine·HCl Hemihydrate',
#  'Aprepitant',
#  'Argatroban',
#  'Aripiprazole',
#  'Arsenic Trioxide',
#  'Artemether',
#  'Articaine·HCl',
#  'Asenapine Maleate',
#  'Aspirin (Acetylsalicylic Acid)',
#  'Atazanavir',
#  'Atomoxetine·HCl',
#  'Atorvastatin Calcium',
#  'Atovaquone',
#  'Atracurium Besylate',
#  'Atropine Sulfate Monohydrate',
#  'Auranofin',
#  'Azacitidine',
#  'Azathioprine',
#  'Azelaic Acid',
#  'Azelastine·HCl',
#  'Azithromycin',
#  'Aztreonam',
#  'Bacitracin',
#  'Baclofen',
#  'Balsalazide',
#  'Beclomethasone Dipropionate',
#  'Benazepril·HCl',
#  'Bendamustine·HCl',
#  'Bendroflumethiazide',
#  'Benztropine Mesylate',
#  'Betaine ',
#  'Betamethasone',
#  'Betaxolol·HCl',
#  'Bethanechol Chloride',
#  'Bexarotene',
#  'Bicalutamide',
#  'Bimatoprost',
#  'Biperiden·HCl',
#  'Bisacodyl',
#  'Bisoprolol Fumarate',
#  'Blank',
#  'Bleomycin Sulfate',
#  'Bortezomib',
#  'Bosentan',
#  'Brimonidine',
#  'Bromfenac ',
#  'Bromocriptine Mesylate',
#  'Brompheniramine Maleate',
#  'Budesonide',
#  'Bumetanide',
#  'Bupivacaine·HCl',
#  'Bupropion ',
#  'Buspirone·HCl',
#  'Busulfan',
#  'Butenafine·HCl',
#  'Butoconazole Nitrate',
#  'Butorphanol-(+)-Tartrate (Schedule Iv)',
#  'Cabergoline',
#  'Caffeine ',
#  'Calcipotriene',
#  'Calcitriol',
#  'Candesartan',
#  'Capecitabine',
#  'Capreomycin Sulfate',
#  'Capsaicin',
#  'Captopril',
#  'Carbachol (Carbamylcholine ) Chloride',
#  'Carbamazepine',
#  'Carbidopa',
#  'Carbinoxamine Maleate',
#  'Carboplatin',
#  'Carglumic Acid',
#  'Carmustine',
#  'Carvedilol',
#  'Cefaclor',
#  'Cefadroxil',
#  'Cefazolin·Na',
#  'Cefdinir',
#  'Cefditoren Pivoxil',
#  'Cefepime·HCl Hydrate',
#  'Cefixime',
#  'Cefotaxime Acid',
#  'Cefotetan Disodium',
#  'Cefoxitin·Na',
#  'Cefpodoxime Proxetil',
#  'Cefprozil',
#  'Ceftazidime',
#  'Ceftibuten',
#  'Ceftizoxim·Na',
#  'Ceftriaxone·Na',
#  'Cefuroxime Axetil',
#  'Cefuroxime·Na',
#  'Cephalexin Monohydrate',
#  'Cetirizine 2HCl',
#  'Chenodiol (Chenodeoxycholic Acid)',
#  'Chlorambucil',
#  'Chloramphenicol',
#  'Chlorhexidine Dihydrochloride',
#  'Chloroquine Diphosphate',
#  'Chlorothiazide',
#  'Chlorpheniramine Maleate',
#  'Chlorpromazine·HCl',
#  'Chlorpropamide',
#  'Chlorthalidone',
#  'Chlorzoxazone',
#  'Ciclesonide',
#  'Ciclopirox',
#  'Cidofovir',
#  'Cilastatin·Na',
#  'Cilostazol',
#  'Cimetidine',
#  'Cinacalcet·HCl',
#  'Ciprofloxacin',
#  'Cisatracurium Besylate',
#  'Cisplatin (Cis-Diamineplatinum(Ii) Dichloride )',
#  'Citalopram·HBr',
#  'Cladribine',
#  'Clarithromycin',
#  'Clavulanate Potassium',
#  'Clemastine Fumarate',
#  'Clindamycin Palmitate·HCl',
#  'Clindamycin·HCl',
#  'Clobetasol Propionate',
#  'Clofarabine',
#  'Clofazimine',
#  'Clomiphene Citrate',
#  'Clomipramine·HCl',
#  'Clonidine·HCl',
#  'Clopidogrel Hydrogen Sulfate ',
#  'Clotrimazole',
#  'Cloxacillin·Na ',
#  'Clozapine',
#  'Colchicine',
#  'Colistimethate·Na',
#  'Colistin Sulfate',
#  'Cortisone Acetate',
#  'Cromolyn·Na (Disodium Cromoglycate)',
#  'Crotamiton',
#  'Cyclobenzaprine·HCl',
#  'Cyclopentolate ',
#  'Cyclophosphamide (Free Base)',
#  'Cycloserine',
#  'Cyclosporine A',
#  'Cyproheptadine·HCl Sesquihydrate',
#  'Cysteamine·HCl',
#  'Cytarabine',
#  'Dacarbazine',
#  'Dactinomycin (= Actinomycin D)',
#  'Dalfampridine (4-Aminopyridine)',
#  'Danazol',
#  'Dantrolene·Na',
#  'Dapsone',
#  'Daptomycin',
#  'Darifenacin·HBr',
#  'Darunavir',
#  'Dasatinib',
#  'Daunorubicin·HCl',
#  'Decitabine',
#  'Deferasirox',
#  'Deferoxamine Mesylate',
#  'Delavirdine Mesylate',
#  'Demeclocycline·HCl',
#  'Desipramine·HCl',
#  'Desloratadine',
#  'Desogestrel',
#  'Desonide',
#  'Desoximetasone',
#  'Desvenlafaxine Succinate Hydrate',
#  'Dexamethasone',
#  'Dexchlorpheniramine Maleate',
#  'Dexmedetomidine·HCl',
#  'Dexrazoxane ',
#  'Dextromethorphan',
#  'Diatrizoate Meglumine',
#  'Diazoxide',
#  'Diclofenac·Na Salt',
#  'Dicloxacillin·Na Salt Monohydrate',
#  'Dicyclomine·HCl',
#  'Didanosine',
#  'Dienogest',
#  'Diflunisal',
#  'Difluprednate',
#  'Digoxin',
#  'Dihydroergotamine Mesylate',
#  'Diltiazem·HCl',
#  'Dimenhydrinate',
#  'Dinoprostone',
#  'Diphenhydramine·HCl',
#  'Dipyridamole',
#  'Disopyramide ',
#  'Disulfiram',
#  'Dobutamine·HCl',
#  'Docetaxel (Taxotere)',
#  'Dofetilide',
#  'Dolasetron',
#  'Donepezil·HCl',
#  'Dopamine·HCl',
#  'Doripenem',
#  'Dorzolamide·HCl',
#  'Doxapram·HCl',
#  'Doxazosin Mesylate',
#  'Doxepin·HCl',
#  'Doxorubicin·HCl',
#  'Doxycycline Monohydrate',
#  'Droperidol',
#  'Drospirenone',
#  'Duloxetine·HCl',
#  'Dutasteride',
#  'Dyphylline',
#  'Econazole Nitrate',
#  'Efavirenz',
#  'Eflornithine·HCl',
#  'Emtricitabine',
#  'Enalapril',
#  'Enalaprilat Maleate',
#  'Entacapone',
#  'Epinastine·HCl',
#  'Epinephrine (L-(-)-Epinephrine-(+)-Bitartrate)',
#  'Epirubicin·HCl',
#  'Eplerenone',
#  'Eprosartan Mesylate',
#  'Eptifibatide',
#  'Erlotinib',
#  'Erythromycin',
#  'Escitalopram ',
#  'Esmolol',
#  'Esomeprazole Potassium',
#  'Estradiol',
#  'Estramustine Phosphate·Na',
#  'Estrone',
#  'Estropipate',
#  'Eszopiclone',
#  'Ethacrynic Acid',
#  'Ethambutol Dihydrochloride',
#  'Ethinyl Estradiol',
#  'Ethionamide',
#  'Ethosuximide',
#  'Etidronate Disodium',
#  'Etodolac',
#  'Etomidate',
#  'Etonogestrel',
#  'Etoposide',
#  'Everolimus',
#  'Exemestane',
#  'Ezetimibe',
#  'Famciclovir',
#  'Famotidine',
#  'Febuxostat',
#  'Felbamate',
#  'Felodipine',
#  'Fenofibrate',
#  'Fenoldopam Mesylate',
#  'Fenoprofen Calcium',
#  'Fexofenadine·HCl',
#  'Finasteride',
#  'Fingolimod',
#  'Flavoxate·HCl',
#  'Flecainide Acetate',
#  'Floxuridine',
#  'Fluconazole',
#  'Flucytosine',
#  'Fludarabine Phosphate',
#  'Fludrocortisone Acetate',
#  'Flumazenil',
#  'Flunisolide',
#  'Fluocinolone Acetonide',
#  'Fluocinonide',
#  'Fluorometholone',
#  'Fluorouracil (5-Fluorouracil)',
#  'Fluoxetine·HCl',
#  'Fluphenazine·HCl',
#  'Flurandrenolide',
#  'Flurbiprofen',
#  'Flutamide',
#  'Fluticasone Propionate',
#  'Fluvastatin·Na',
#  'Fluvoxamine Maleate',
#  'Fomepizole',
#  'Formoterol',
#  'Foscarnet·Na (Sodium Phosphonoformate Tribasic Hexahydrate) ',
#  'Fosfomycin Calcium',
#  'Fosinopril·Na',
#  'Fosphenytoin·Na Pentahydrate',
#  'Fulvestrant',
#  'Furosemide',
#  'Gabapentin',
#  'Galantamine·HBr',
#  'Ganciclovir',
#  'Gatifloxacin',
#  'Gefitinib',
#  'Gemcitabine·HCl',
#  'Gemfibrozil',
#  'Gemifloxacin ',
#  'Gentamycin Sulfate',
#  'Glimepiride',
#  'Glipizide',
#  'Glyburide',
#  'Glycopyrrolate Iodide',
#  'Goserelin Acetate',
#  'Granisetron·HCl',
#  'Griseofulvin',
#  'Guanabenz Acetate ',
#  'Guanfacine·HCl',
#  'Guanidine·HCl',
#  'Halcinonide',
#  'Halobetasol Propionate',
#  'Haloperidol ',
#  'Hexachlorophene',
#  'Homatropine Methylbromide',
#  'Hydralazine·HCl',
#  'Hydrochlorothiazide',
#  'Hydrocortisone',
#  'Hydrocortisone Acetate',
#  'Hydroflumethiazide',
#  'Hydroxocobalamin·HCl',
#  'Hydroxychloroquine Sulfate',
#  'Hydroxyurea',
#  'Hydroxyzine Dihydrochloride',
#  'Ibandronate·Na Monohydrate',
#  'Ibuprofen',
#  'Ibutilide Fumarate',
#  'Idarubicin·HCl',
#  'Idoxuridine',
#  'Ifosfamide',
#  'Iloperidone',
#  'Imatinib Mesylate',
#  'Imipenem',
#  'Imipramine·HCl',
#  'Imiquimod',
#  'Indapamide',
#  'Indinavir ',
#  'Indomethacin',
#  'Ipratropium·Br',
#  'Irbesartan',
#  'Irinotecan·HCl',
#  'Isocarboxazid',
#  'Isoniazid',
#  'Isosorbide Dinitrate',
#  'Isotretinoin (13-Cis-Retinoic Acid)',
#  'Isradipine',
#  'Itraconazole',
#  'Ivermectin',
#  'Kanamycin Sulfate',
#  'Ketoconazole',
#  'Ketoprofen',
#  'Ketorolac Tromethamine',
#  'Ketotifen Fumarate',
#  'L-Ascorbic Acid',
#  'Labetalol·HCl',
#  'Lacosamide',
#  'Lactulose',
#  'Lamivudine',
#  'Lamotrigine',
#  'Lansoprazole',
#  'Lapatinib Ditosylate',
#  'Latanoprost',
#  'Leflunomide',
#  'Lenalidomide',
#  'Letrozole',
#  'Leucovorin Calcium Pentahydrate',
#  'Levalbuterol·HCl',
#  'Levetiracetam',
#  'Levobunolol·HCl',
#  'Levocarnitine',
#  'Levocetirizine Dihydrochloride',
#  'Levofloxacin·HCl',
#  'Levonorgestrel',
#  'Levothyroxine·Na',
#  'Lidocaine·HCl·H2O',
#  'Lincomycin·HCl',
#  'Liothyronine·Na',
#  'Lisinopril·2H2O',
#  'Lomustine',
#  'Loperamide·HCl',
#  'Lopinavir',
#  'Loratadine',
#  'Losartan Potassium',
#  'Loteprednol Etabonate',
#  'Lovastatin',
#  'Loxapine Succinate',
#  'Mafenide·HCl',
#  'Malathion',
#  'Mannitol',
#  'Maprotiline·HCl',
#  'Maraviroc',
#  'Mebendazole',
#  'Meclizine Dihydrochloride',
#  'Meclofenamate·Na',
#  'Medroxyprogesterone Acetate',
#  'Mefenamic Acid',
#  'Mefloquine·HCl',
#  'Megestrol Acetate',
#  'Meloxicam',
#  'Melphalan',
#  'Memantine·HCl',
#  'Mepenzolate Bromide',
#  'Mepivacaine·HCl',
#  'Mequinol',
#  'Mercaptopurine Hydrate',
#  'Meropenem',
#  'Mesalamine (5-Aminosalicylic Acid)',
#  'Mesna',
#  'Mestranol',
#  'Metaproterenol Hemisulfate (Orciprenaline)',
#  'Metaraminol Bitartrate',
#  'Metaxalone',
#  'Metformin·HCl',
#  'Methacholine Chloride',
#  'Methazolamide',
#  'Methenamine Hippurate',
#  'Methimazole',
#  'Methocarbamol',
#  'Methotrexate ',
#  'Methoxsalen (Xanthotoxin)',
#  'Methscopolamine Bromide ((−)-Scopolamine Methyl Bromide)',
#  'Methsuximide',
#  'Methyclothiazide',
#  'Methyl Aminolevulinate·HCl',
#  'Methyldopa Sesquihydrate (L-Α-Methyl-Dopa Sesquihyrate)',
#  'Methylergonovine Maleate',
#  'Methylprednisolone',
#  'Metoclopramide·HCl',
#  'Metolazone',
#  'Metoprolol Tartrate',
#  'Metronidazole',
#  'Metyrapone',
#  'Mexiletine·HCl',
#  'Micafungin ',
#  'Miconazole',
#  'Midodrine·HCl',
#  'Mifepristone',
#  'Miglitol',
#  'Miglustat (N-Butyldeoxynojirimycin·HCl)',
#  'Milnacipran·HCl',
#  'Milrinone',
#  'Minocycline ',
#  'Minoxidil',
#  'Mirtazapine',
#  'Misoprostol',
#  'Mitomycin C',
#  'Mitotane',
#  'Mitoxantrone·HCl',
#  'Moexipril·HCl',
#  'Mometasone Furoate',
#  'Montelukast·Na',
#  'Moxifloxacin·HCl',
#  'Mupirocin',
#  'Mycophenolate Mofetil',
#  'Mycophenolic Acid',
#  'Nabumetone',
#  'Nadolol',
#  'Nafcillin·Na',
#  'Naftifine·HCl',
#  'Nalbuphine·HCl Dihydrate',
#  'Naloxone·HCl',
#  'Naltrexone·HCl',
#  'Naphazoline·HCl',
#  'Naproxen',
#  'Naratriptan·HCl',
#  'Natamycin',
#  'Nateglinide',
#  'Nebivolol·HCl',
#  'Nefazodone·HCl',
#  'Nelarabine',
#  'Nelfinavir Mesylate',
#  'Neomycin Sulfate',
#  'Nepafenac',
#  'Nevirapine',
#  'Niacin (Known As Vitamin B3, Nicotinic Acid And Vitamin Pp) ',
#  'Nicardipine·HCl',
#  'Nicotine',
#  'Nifedipine',
#  'Nilotinib',
#  'Nilutamide',
#  'Nimodipine',
#  'Nisoldipine',
#  'Nitazoxanide',
#  'Nitisinone',
#  'Nitrofurantoin',
#  'Nizatidine',
#  'Norepinephrine Bitartrate Monohydrate',
#  'Norethindrone',
#  'Norfloxacin',
#  'Nortriptyline·HCl',
#  'Nystatin',
#  'Ofloxacin',
#  'Olanzapine',
#  'Olmesartan',
#  'Olopatadine',
#  'Olsalazine·Na',
#  'Omeprazole',
#  'Ondansetron',
#  'Orlistat (Tetrahydrolipstatin)',
#  'Orphenadrine Citrate',
#  'Oseltamivir Phosphate',
#  'Oxacillin·Na',
#  'Oxaliplatin',
#  'Oxaprozin',
#  'Oxcarbazepine',
#  'Oxiconazole Nitrate',
#  'Oxtriphylline',
#  'Oxybutynin Chloride',
#  'Oxytetracycline·HCl',
#  'Paclitaxel (Taxol)',
#  'Paliperidone',
#  'Palonosetron·HCl',
#  'Pamidronate Disodium  Pentahydrate (Pamidronic Acid)',
#  'Pancuronium·2Br',
#  'Pantoprazole',
#  'Paromomycin Sulfate',
#  'Paroxetine·HCl',
#  'Pazopanib·HCl',
#  'Pemetrexed Disodium',
#  'Pemirolast Potassium',
#  'Penciclovir',
#  'Penicillamine (D-Penicillamine)',
#  'Penicillin G Potassium (Benzylpenicillin)',
#  'Penicillin V Potassium',
#  'Pentamidine Isethionate',
#  'Pentostatin',
#  'Pentoxifylline',
#  'Perindopril Erbumine',
#  'Permethrin',
#  'Perphenazine',
#  'Phenelzine Sulfate',
#  'Phenoxybenzamine·HCl',
#  'Phentolamine·HCl',
#  'Phenylephrine ',
#  'Phenytoin',
#  'Phytonadione',
#  'Pilocarpine·HCl',
#  'Pimecrolimus',
#  'Pimozide',
#  'Pindolol',
#  'Pioglitazone·HCl',
#  'Piperacillin',
#  'Piroxicam',
#  'Pitavastatin Calcium',
#  'Podofilox',
#  'Posaconazole',
#  'Pralidoxime Chloride',
#  'Pramipexole Dihydrochloride Monohydrate',
#  'Prasugrel',
#  'Pravastatin·Na',
#  'Praziquantel',
#  'Prazosin·HCl',
#  'Prednisolone',
#  'Prednisone',
#  'Prilocaine·HCl',
#  'Primaquine Phosphate',
#  'Primidone',
#  'Probenecid',
#  'Procainamide·HCl',
#  'Procarbazine·HCl',
#  'Progesterone',
#  'Promethazine·HCl',
#  'Propafenone·HCl',
#  'Proparacaine·HCl',
#  'Propofol',
#  'Propranolol·HCl',
#  'Propylthiouracil',
#  'Protriptyline·HCl',
#  'Pyrazinamide',
#  'Pyridostigmine Bromide',
#  'Pyrimethamine',
#  'Quetiapine Fumarate',
#  'Quinapril·HCl',
#  'Quinidine·HCl·H2O',
#  'Quinine·HCl·H2O',
#  'Rabeprazole·Na',
#  'Raloxifene·HCl',
#  'Raltegravir',
#  'Ramelteon',
#  'Ramipril',
#  'Ranitidine·HCl',
#  'Ranolazine·2HCl',
#  'Rasagiline Mesylate',
#  'Regadenoson',
#  'Repaglinide',
#  'Reserpine',
#  'Ribavirin',
#  'Rifabutin',
#  'Rifampin (Rifampicin)',
#  'Rifapentine',
#  'Rifaximin',
#  'Riluzole·HCl',
#  'Rimantadine·HCl',
#  'Risperidone',
#  'Risredonic Acid',
#  'Ritonavir',
#  'Rivastigmine Tartrate',
#  'Rizatriptan Benzoate',
#  'Rocuronium Bromide',
#  'Ropinirole·HCl',
#  'Ropivacaine·HCl Monohydrate',
#  'Rosiglitazone ',
#  'Rosuvastatin Calcium',
#  'Rufinamide',
#  'Salbutamol Hemisulfate',
#  'Salmeterol ',
#  'Saquinavir Mesylate',
#  'Scopolamine·HBr',
#  'Sertaconazole',
#  'Sertraline·HCl',
#  'Sildenafil Citrate',
#  'Silver Sulfadiazine',
#  'Simvastatin',
#  'Sirolimus (Rapamycin)',
#  'Sitagliptin Phosphate',
#  'Sodium Phenylbutyrate',
#  'Sorafenib Tosylate',
#  'Sotalol·HCl',
#  'Spectinomycin·HCl Pentahydrate',
#  'Spironolactone',
#  'Stavudine',
#  'Streptomycin Sulfate',
#  'Streptozocin',
#  'Succinylcholine Chloride·2H2O',
#  'Sulconazole Nitrate',
#  'Sulfacetamide·Na',
#  'Sulfadiazine',
#  'Sulfamethoxazole',
#  'Sulfanilamide',
#  'Sulfasalazine',
#  'Sulindac',
#  'Sumatriptan Succinate',
#  'Tacrine·HCl',
#  'Tacrolimus (Fk506)',
#  'Tadalafil',
#  'Tamoxifen Citrate',
#  'Tamsulosin·HCl',
#  'Tazarotene',
#  'Telbivudine ',
#  'Telithromycin',
#  'Telmisartan',
#  'Temozolomide',
#  'Teniposide',
#  'Tenofovir',
#  'Terazosin·HCl',
#  'Terbinafine·HCl',
#  'Terbutaline Hemisulfate',
#  'Terconazole',
#  'Testosterone Enanthate',
#  'Tetrabenazine',
#  'Tetracycline',
#  'Tetrahydrozoline·HCl',
#  'Thalidomide',
#  'Theophylline',
#  'Thioguanine (6-Thioguanine)',
#  'Thioridazine·HCl',
#  'Thiotepa',
#  'Tiagabine·HCl',
#  'Ticlopidine·HCl',
#  'Tigecycline',
#  'Tiludronate Disodium',
#  'Tinidazole',
#  'Tiopronin',
#  'Tiotropium Bromide Monohydrate',
#  'Tirofiban·HCl',
#  'Tizanidine·HCl',
#  'Tobramycin',
#  'Tolazamide',
#  'Tolbutamide',
#  'Tolcapone',
#  'Tolmetin·Na',
#  'Tolterodine Tartrate',
#  'Tolvaptan',
#  'Topiramate',
#  'Topotecan·HCl',
#  'Toremifene Base',
#  'Torsemide',
#  'Tramadol·HCl',
#  'Trandolapril',
#  'Tranexamic Acid',
#  'Tranylcypromine Hemisulfate',
#  'Travoprost',
#  'Trazodone·HCl',
#  'Tretinoin',
#  'Triamcinolone Acetonide',
#  'Triamterene',
#  'Trientine Dihydrochloride',
#  'Trifluoperazine·HCl',
#  'Trihexyphenidyl·HCl',
#  'Trimethadione',
#  'Trimethobenzamide·HCl',
#  'Trimethoprim',
#  'Trimipramine Maleate',
#  'Triptorelin Acetate',
#  'Tropicamide',
#  'Trospium Chloride',
#  'Ursodiol',
#  'Valacyclovir·HCl',
#  'Valganciclovir·HCl',
#  'Valproate·Na',
#  'Valproic Acid',
#  'Valsartan',
#  'Vancomycin·HCl',
#  'Vardenafil ',
#  'Vecuronium Bromide',
#  'Venlafaxine·HCl',
#  'Verapamil·HCl',
#  'Vigabatrin',
#  'Vinblastine Sulfate',
#  'Vincristine Sulfate',
#  'Vinorelbine ',
#  'Voriconazole',
#  'Vorinostat',
#  'Warfarin·Na',
#  'Zafirlukast',
#  "Zalcitabine (2',3'-Dideoxycytidine)",
#  'Zaleplon',
#  'Zanamivir',
#  "Zidovudine (3'-Azido-3'-Deoxythymidine)",
#  'Zileuton',
#  'Ziprasidone ',
#  'Zoledronic Acid Monohydrate',
#  'Zolmitriptan',
#  'Zonisamide',
#  'blank']
