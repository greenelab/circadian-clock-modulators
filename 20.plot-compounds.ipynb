# %% [markdown]
# # Visualize Tamai et al screen data

# %%
import pandas

import plotly.graph_objects as go
import plotly.express as px

# %%
screen_df = pandas.read_table("data/tamai-screen/combined-results.tsv")
screen_df.notes.fillna("", inplace=True)
screen_df.head(2)
# Out:
#      compound_name compound_set concentration  period_before  period_change  \
# 0  Clindamycin·HCl          fda          1 uM           21.5        0.02917
# 1        Felbamate          fda          1 uM           21.7        0.06250
#
#    plate notes
# 0      1
# 1      1

# %%
fig = px.scatter(
    data_frame=screen_df.reset_index(),
    x="compound_name",
    y="period_change",
    facet_row="concentration",
    facet_col="compound_set",
    hover_name="compound_name",
    hover_data=["notes", "period_before", "compound_set"],
    # same y-axis range as Figure 1A of Tamai et al.
    range_y=(-2, 5),
    labels={"period_change": "Period Change (hours)", "concentration": "Concentration"},
)
fig.update_xaxes(matches=None, showticklabels=False, title_text=None)
fig.show(renderer="notebook_connected")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="ccbe0e92-07eb-4e21-8950-3c4a151108e5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ccbe0e92-07eb-4e21-8950-3c4a151108e5")) {
#                     Plotly.newPlot(
#                         'ccbe0e92-07eb-4e21-8950-3c4a151108e5',
#                         [{"customdata": [["", 21.5, "fda"], ["", 21.7, "fda"], ["", 21.6, "fda"], ["", 21.4, "fda"], ["", 21.5, "fda"], ["", 21.5, "fda"], ["", 22.1, "fda"], ["", 21.7, "fda"], ["", 21.4, "fda"], ["", 21.6, "fda"], ["", 21.5, "fda"], ["", 21.5, "fda"], ["", 21.6, "fda"], ["", 21.3, "fda"], ["", 21.5, "fda"], ["", 21.5, "fda"], ["", 21.5, "fda"], ["", 21.5, "fda"], ["", 21.6, "fda"], ["", 21.5, "fda"], ["", 21.3, "fda"], ["", 21.6, "fda"], ["", 21.7, "fda"], ["", 21.5, "fda"], ["", 21.5, "fda"], ["", 21.5, "fda"], ["", 21.5, "fda"], ["", 21.3, "fda"], ["", 21.7, "fda"], ["", 21.5, "fda"], ["", 21.3, "fda"], ["", 21.6, "fda"], ["", 21.6, "fda"], ["", 21.5, "fda"], ["", 21.3, "fda"], ["", 21.4, "fda"], ["", 21.7, "fda"], ["", 21.5, "fda"], ["", 21.5, "fda"], ["", 21.6, "fda"], ["", 21.4, "fda"], ["", 21.4, "fda"], ["", 21.5, "fda"], ["", 21.6, "fda"], ["", 21.7, "fda"], ["", 21.5, "fda"], ["", 21.6, "fda"], ["", 21.5, "fda"], ["", 21.4, "fda"], ["", 21.4, "fda"], ["", 21.5, "fda"], ["", 21.4, "fda"], ["", 21.4, "fda"], ["", 21.6, "fda"], ["", 21.6, "fda"], ["", 21.8, "fda"], ["", 21.5, "fda"], ["", 21.6, "fda"], ["", 21.6, "fda"], ["", 21.4, "fda"], ["", 21.5, "fda"], ["", 21.6, "fda"], ["", 21.6, "fda"], ["", 21.7, "fda"], ["", 21.5, "fda"], ["", 21.5, "fda"], ["", 21.4, "fda"], ["", 21.5, "fda"], ["", 21.5, "fda"], ["", 21.6, "fda"], ["", 21.5, "fda"], ["", 21.7, "fda"], ["", 21.6, "fda"], ["", 21.4, "fda"], ["", 21.7, "fda"], ["", 21.1, "fda"], ["dead", 59.9, "fda"], ["", 21.6, "fda"], ["", 21.5, "fda"], ["", 21.5, "fda"], ["", 21.6, "fda"], ["", 21.6, "fda"], ["", 21.7, "fda"], ["", 21.6, "fda"], ["", 21.6, "fda"], ["", 21.5, "fda"], ["", 21.7, "fda"], ["", 21.4, "fda"], ["", 21.6, "fda"], ["", 21.7, "fda"], ["", 21.7, "fda"], ["", 21.7, "fda"], ["", 21.6, "fda"], ["", 21.8, "fda"], ["", 21.5, "fda"], ["", 21.5, "fda"], ["", 21.6, "fda"], ["", 21.4, "fda"], ["", 21.7, "fda"], ["", 21.6, "fda"], ["", 21.7, "fda"], ["dead", 59.9, "fda"], ["", 21.6, "fda"], ["", 21.7, "fda"], ["", 21.6, "fda"], ["", 21.5, "fda"], ["", 21.7, "fda"], ["", 21.8, "fda"], ["", 21.9, "fda"], ["", 21.6, "fda"], ["", 21.5, "fda"], ["", 21.5, "fda"], ["", 21.7, "fda"], ["", 21.4, "fda"], ["", 21.6, "fda"], ["", 21.4, "fda"], ["", 21.4, "fda"], ["", 21.7, "fda"], ["", 21.4, "fda"], ["", 21.5, "fda"], ["", 21.7, "fda"], ["", 21.4, "fda"], ["", 21.5, "fda"], ["", 21.5, "fda"], ["", 21.6, "fda"], ["", 21.5, "fda"], ["", 21.6, "fda"], ["", 21.5, "fda"], ["", 21.6, "fda"], ["", 21.6, "fda"], ["", 21.6, "fda"], ["", 21.6, "fda"], ["", 21.4, "fda"], ["", 21.4, "fda"], ["", 21.5, "fda"], ["", 21.7, "fda"], ["", 21.7, "fda"], ["", 21.6, "fda"], ["", 21.6, "fda"], ["", 21.6, "fda"], ["", 21.6, "fda"], ["", 21.7, "fda"], ["", 21.6, "fda"], ["", 22.1, "fda"], ["", 22.2, "fda"], ["", 21.4, "fda"], ["", 21.5, "fda"], ["", 21.6, "fda"], ["", 21.7, "fda"], ["", 21.6, "fda"], ["", 21.6, "fda"], ["", 21.8, "fda"], ["", 21.7, "fda"], ["", 21.5, "fda"], ["", 21.5, "fda"], ["", 21.6, "fda"], ["", 21.5, "fda"], ["", 21.7, "fda"], ["", 21.7, "fda"], ["", 21.5, "fda"], ["", 21.6, "fda"], ["", 21.7, "fda"], ["", 21.6, "fda"], ["", 21.7, "fda"], ["", 21.1, "fda"], ["", 21.5, "fda"], ["", 21.7, "fda"], ["", 21.5, "fda"], ["", 21.7, "fda"], ["", 21.6, "fda"], ["", 21.5, "fda"], ["", 21.6, "fda"], ["", 21.5, "fda"], ["", 21.7, "fda"], ["", 21.6, "fda"], ["", 21.8, "fda"], ["", 21.6, "fda"], ["", 21.6, "fda"], ["", 21.6, "fda"], ["", 21.5, "fda"], ["", 21.6, "fda"], ["", 21.5, "fda"], ["", 21.7, "fda"], ["", 21.6, "fda"], ["", 21.7, "fda"], ["", 21.8, "fda"], ["", 21.6, "fda"], ["", 21.6, "fda"], ["", 21.5, "fda"], ["", 21.5, "fda"], ["", 21.6, "fda"], ["", 21.0, "fda"], ["", 21.8, "fda"], ["", 21.5, "fda"], ["", 21.7, "fda"], ["", 21.7, "fda"], ["", 21.6, "fda"], ["", 21.6, "fda"], ["", 21.7, "fda"], ["", 21.6, "fda"], ["", 21.8, "fda"], ["", 21.9, "fda"], ["", 21.6, "fda"], ["", 21.5, "fda"], ["", 21.7, "fda"], ["", 21.7, "fda"], ["", 21.7, "fda"], ["", 21.8, "fda"], ...

# %% [markdown]
# Compare to Figure 1A from [Tamai et al](https://doi.org/10.15252/emmm.201708724):
#
# > ![Figure 1A from Tamai et al](https://www.embopress.org/cms/asset/8b16fca1-f8a6-4de3-baa1-66924671a46a/emmm201708724-fig-0001-m.jpg)
